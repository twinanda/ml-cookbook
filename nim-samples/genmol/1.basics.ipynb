# %% [markdown]
# # GenMol - Basics

# %% [markdown]
# GenMol is a masked diffusion model trained on molecular SAFE representations for fragment-based molecule generation.  GenMol a generalist model for various drug discovery tasks, including de novo generation, linker design, motif extension, scaffold decoration/morphing, hit generation, and lead optimization.
#
# In this notebook, we discuss conversion between SMILES and SAFE molecular representations, and demonstrate *de novo* generation, fragment completion for motif extension and scaffold decoration, and superstructure generation.  We also assess the generated molecules for validity and uniqueness.
#
# ## Setup
# Refer to [README.md](README.md) to deploy the GenMol NIM. Make sure that you have your GenMol NIM deployed, and the python requirements installed.
# Update the host, username, and password used in the GenMol_Generator for your NIM deployment.
#
# First, we need to import a few dependencies and configure our GenMol interface to point to the NIM `/generate`
# interface.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.3.2)
# Requirement already satisfied: numpy in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: rdkit in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (2025.3.6)
# Collecting transformers==4.51.3 (from -r requirements.txt (line 4))
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting safe-mol (from -r requirements.txt (line 5))
#   Downloading safe_mol-0.1.13-py3-none-any.whl.metadata (11 kB)
# Collecting datamol (from -r requirements.txt (line 6))
#   Downloading datamol-0.12.5-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: matplotlib in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (3.10.6)
# Collecting filelock (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.34.6-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from transformers==4.51.3->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from transformers==4.51.3->-r requirements.txt (line 4)) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading regex-2025.9.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from transformers==4.51.3->-r requirements.txt (line 4)) (2.32.5)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.3 (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3->-r requirements.txt (line 4)) (4.15.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3->-r requirements.txt (line 4))
#   Downloading hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: Pillow in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from rdkit->-r requirements.txt (line 3)) (11.3.0)
# Collecting loguru (from safe-mol->-r requirements.txt (line 5))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting typer (from safe-mol->-r requirements.txt (line 5))
#   Downloading typer-0.17.4-py3-none-any.whl.metadata (15 kB)
# Collecting universal_pathlib (from safe-mol->-r requirements.txt (line 5))
#   Downloading universal_pathlib-0.2.6-py3-none-any.whl.metadata (25 kB)
# Collecting torch>=2.0 (from safe-mol->-r requirements.txt (line 5))
#   Downloading torch-2.8.0-cp313-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Collecting datasets (from safe-mol->-r requirements.txt (line 5))
#   Downloading datasets-4.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting accelerate (from safe-mol->-r requirements.txt (line 5))
#   Downloading accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting evaluate (from safe-mol->-r requirements.txt (line 5))
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting wandb (from safe-mol->-r requirements.txt (line 5))
#   Downloading wandb-0.21.4-py3-none-macosx_12_0_arm64.whl.metadata (10 kB)
# Collecting joblib (from datamol->-r requirements.txt (line 6))
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting scipy (from datamol->-r requirements.txt (line 6))
#   Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting selfies (from datamol->-r requirements.txt (line 6))
#   Downloading selfies-2.2.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: platformdirs in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from datamol->-r requirements.txt (line 6)) (4.4.0)
# Collecting scikit-learn (from datamol->-r requirements.txt (line 6))
#   Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting importlib-resources (from datamol->-r requirements.txt (line 6))
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 7)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from matplotlib->-r requirements.txt (line 7)) (3.2.4)
# Requirement already satisfied: six>=1.5 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: setuptools in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from torch>=2.0->safe-mol->-r requirements.txt (line 5)) (80.9.0)
# Collecting sympy>=1.13.3 (from torch>=2.0->safe-mol->-r requirements.txt (line 5))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.0->safe-mol->-r requirements.txt (line 5))
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from torch>=2.0->safe-mol->-r requirements.txt (line 5)) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0->safe-mol->-r requirements.txt (line 5))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: psutil in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from accelerate->safe-mol->-r requirements.txt (line 5)) (7.0.0)
# Collecting pyarrow>=21.0.0 (from datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading xxhash-3.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5)) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5))
#   Downloading yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets->safe-mol->-r requirements.txt (line 5)) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from requests->transformers==4.51.3->-r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from requests->transformers==4.51.3->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from requests->transformers==4.51.3->-r requirements.txt (line 4)) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from jinja2->torch>=2.0->safe-mol->-r requirements.txt (line 5)) (3.0.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->datamol->-r requirements.txt (line 6))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting click>=8.0.0 (from typer->safe-mol->-r requirements.txt (line 5))
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer->safe-mol->-r requirements.txt (line 5))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer->safe-mol->-r requirements.txt (line 5))
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer->safe-mol->-r requirements.txt (line 5))
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/andru/Documents/.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer->safe-mol->-r requirements.txt (line 5)) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->safe-mol->-r requirements.txt (line 5))
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading sentry_sdk-2.38.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3->wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3->wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->safe-mol->-r requirements.txt (line 5))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 51.5 MB/s eta 0:00:0000:01
# Downloading huggingface_hub-0.34.6-py3-none-any.whl (562 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.6/562.6 kB 23.5 MB/s eta 0:00:00
# Downloading hf_xet-1.1.10-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 54.8 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 53.9 MB/s eta 0:00:00
# Downloading safe_mol-0.1.13-py3-none-any.whl (60 kB)
# Downloading datamol-0.12.5-py3-none-any.whl (495 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading regex-2025.9.1-cp313-cp313-macosx_11_0_arm64.whl (286 kB)
# Downloading safetensors-0.6.2-cp38-abi3-macosx_11_0_arm64.whl (432 kB)
# Downloading torch-2.8.0-cp313-none-macosx_11_0_arm64.whl (73.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 MB 69.0 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 68.9 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 18.0 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading datasets-4.1.0-py3-none-any.whl (503 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-macosx_11_0_arm64.whl (466 kB)
# Downloading multidict-6.6.4-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading yarl-1.20.1-cp313-cp313-macosx_11_0_arm64.whl (88 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-macosx_11_0_arm64.whl (45 kB)
# Downloading propcache-0.3.2-cp313-cp313-macosx_11_0_arm64.whl (41 kB)
# Downloading pyarrow-21.0.0-cp313-cp313-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 66.9 MB/s eta 0:00:00a 0:00:01
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.9 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 60.7 MB/s eta 0:00:00
# Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 64.7 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading selfies-2.2.0-py3-none-any.whl (36 kB)
# Downloading typer-0.17.4-py3-none-any.whl (46 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading universal_pathlib-0.2.6-py3-none-any.whl (50 kB)
# Downloading wandb-0.21.4-py3-none-macosx_12_0_arm64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 59.8 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-6.32.1-cp39-abi3-macosx_10_9_universal2.whl (426 kB)
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 50.7 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sentry_sdk-2.38.0-py2.py3-none-any.whl (370 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp313-cp313-macosx_11_0_arm64.whl (30 kB)
# Installing collected packages: mpmath, xxhash, typing-inspection, tqdm, threadpoolctl, sympy, smmap, shellingham, sentry-sdk, selfies, scipy, safetensors, regex, pydantic-core, pyarrow, protobuf, propcache, networkx, multidict, mdurl, loguru, joblib, importlib-resources, hf-xet, fsspec, frozenlist, filelock, dill, click, annotated-types, aiohappyeyeballs, yarl, universal_pathlib, torch, scikit-learn, pydantic, multiprocess, markdown-it-py, huggingface-hub, gitdb, aiosignal, tokenizers, rich, gitpython, datamol, aiohttp, accelerate, wandb, typer, transformers, datasets, evaluate, safe-mol
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/53 [sympy]

# %%
from genmol import GenMol_Generator
from utils import Utils

from rdkit import Chem
from rdkit.Chem import Draw

# SAFE <> SMILES conversion
import safe as sf
import datamol as dm

host = '<host>' # TODO: Fill in with the deployed NIM URL, without http://, https:// and forward slashes
username = '<username>' # TODO: Fill in with username from deployment
password = '<password>' # TODO: Fill in with password from deployment
invoke_url = f'https://{username}:{password}@{host}/generate'
gm = GenMol_Generator(invoke_url = invoke_url)

# %% [markdown]
# ## Introduction to GenMol and the use of SAFE, SMILES, and masks.
#
# GenMol is a masked diffusion model trained on molecular Sequential Attachmentbased Fragment Embeddings, or [SAFE representations](https://arxiv.org/abs/2310.10773) for fragment-based molecule generation.  The GenMol NIM accepts both SMILES and SAFE molecular representations as input, but the use of SAFE representations allow explicit specification of fragments, attachment points, and regions of molecule to be masked.  It is important to note that SAFE representations are order invariant, so that the structure of explicitly specified fragments and masked, generated fragments are determined based on attachment points regardless of the order in which the fragments and mask are specified.
#
# The SAFE representation is composed of molecule fragments separated by a `.` token.  These fragments can be coupled with a mask of the form `[*{min_tokens-mask_tokens}]`.  A pure mask can be input without any additional fragments for de novo molecule generation as shown below.  For example, a pure mask of `[*{20-30}]` will return molecules generated with a minimum of 20 and maximum of 30 tokens.  Additional examples are provided that demonstrate the combination of molecule fragments and mask for motif extension and scaffold decoration.
#
# Before diving into the examples, it is useful to see how to translate between SMILES and SAFE representations.  The next few cells demonstrate how to convert between SMILES and SAFE and visualize the results using the [`datamol/safe`](https://github.com/datamol-io/safe) package.  Additional examples can be found in the [SAFE docs](https://safe-docs.datamol.io/stable/).
#
# First, display an example molecule using its SMILES representation.

# %%
testsmiles = "CCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ncnc4[nH]ccc34)cn2)C1"
testmol = dm.to_mol(testsmiles)
display(dm.to_image(testmol))

# %% [markdown]
# Then use the SAFE encoder to generate the SAFE fragment-based representation.

# %%
safe_str = sf.encode(testmol)
print(f"SMILES: {testsmiles}")
print(f"SAFE:   {safe_str}\n represented using {len(safe_str.split('.'))} fragments")
# Out:
# SMILES: CCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ncnc4[nH]ccc34)cn2)C1
# SAFE:   c18ncnc2[nH]ccc12.N15CC67C1.n17cc8cn1.CCS5(=O)=O.C6C#N
#  represented using 5 fragments

# %% [markdown]
# Then use the `datamol` `to_mol()` function to reconstruct the molecule from the SAFE string.

# %%
testreconstructed = dm.to_mol(safe_str)
display(dm.to_image(testreconstructed))

# %% [markdown]
# We can also visualize the molecule, highlighting the individual fragments that compose it.

# %%
sf.to_image(safe_str)

# %% [markdown]
# The examples above demonstrate how to manually use the `datamol/safe` package to convert between SMILES and SAFE representations.  In the examples that follow, we will use the provided `Utils` package that provides utilities for converting and managing fragments and attachment points.

# %% [markdown]
# ## De novo Generation

# %%
molecules = gm.inference(smiles = '[*{15-25}]', num_molecules = 20)[:12]

# %%
ms = [Chem.MolFromSmiles(_['smiles']) for _ in molecules]

# %%
Draw.MolsToGridImage(ms, molsPerRow=4, subImgSize=(240, 150), legends=['QED ' + str(_['score']) for _ in molecules])

# %% [markdown]
# ## Fragment Completion
#
# ### Motif-Extension or Scaffold-Decoration

# %%
smiles_full = 'CCS(=O)(=O)N1CC(CC#N)(n2cc(-c3ncnc4[nH]ccc34)cn2)C1'
Draw.MolToImage(Chem.MolFromSmiles(smiles_full))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
smiles = '[2*]C1(CC#N)CN(S(=O)(=O)CC)C1'
Draw.MolToImage(Chem.MolFromSmiles(smiles))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
safe = Utils.smiles2safe(smiles)
safe
# Out:
# 'C124CN3C1.S3(=O)(=O)CC.C4C#N'

# %%
molecules = gm.inference(smiles = safe + '.[*{15-25}]', num_molecules = 100, temperature = 2.0, noise = 1.0)[:12]
len(molecules)
# Out:
# 12

# %%
ms = [Chem.MolFromSmiles(_['smiles']) for _ in molecules]

# %%
Draw.MolsToGridImage(ms, molsPerRow=4, subImgSize=(240, 150), legends=['QED ' + str(_['score']) for _ in molecules])

# %% [markdown]
# ## Superstructure Generation

# %%
smiles = 'c1nc(-c2cnn(C3CNC3)c2)c2cc[nH]c2n1'
Draw.MolToImage(Chem.MolFromSmiles(smiles))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
cores = Utils.attachable_points(smiles)[:6]
ms = [Chem.MolFromSmiles(_) for _ in cores]
Draw.MolsToGridImage(ms, molsPerRow=3, subImgSize=(300, 200), legends=['QED ' + str(_['score']) for _ in molecules])

# %%
safes = [Utils.smiles2safe(_) for _ in cores]
molecules = [gm.inference(smiles = _ + '.[*{15-15}]', num_molecules = 10, temperature = 1.5, noise = 1.0)[0] for _ in safes]

# %%
smiless = [_['smiles'] for _ in molecules]
ms = [Chem.MolFromSmiles(_) for _ in smiless]
Draw.MolsToGridImage(ms, molsPerRow=3, subImgSize=(300, 200), legends=['QED ' + str(_['score']) for _ in molecules])

# %% [markdown]
# ## Benchmarks for Validity and Uniqueness

# %%
smiles = '[11*]C1(CC#N)CN(S(=O)(=O)CC)C1'
safe = Utils.smiles2safe(smiles)
safe
# Out:
# 'C124CN3C1.S3(=O)(=O)CC.C4C#N'

# %%
nsample = 100
ntest = 50

def test():
    molecules = gm.inference(smiles = safe + '.[*{17-17}]', num_molecules = nsample, temperature = 1.2, noise = 1.6, unique = False)
    return len(molecules)/nsample, len(set([_['smiles'] for _ in molecules]))/nsample

data = [test() for _ in range(ntest)]

# %%
import pandas as pd
pd.DataFrame(data, columns = ['validity', 'uniqueness']).describe(percentiles=[])
# Out:
#         validity  uniqueness
# count  50.000000   50.000000
# mean    0.989600    0.770000
# std     0.010872    0.038173
# min     0.950000    0.670000
# 50%     0.990000    0.770000
# max     1.000000    0.840000

# %%
import matplotlib.pyplot as plt
pd.DataFrame(data, columns = ['validity', 'uniqueness']).hist(bins=10)
# Out:
# array([[<Axes: title={'center': 'validity'}>,
#         <Axes: title={'center': 'uniqueness'}>]], dtype=object)
